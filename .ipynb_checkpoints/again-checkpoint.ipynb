# %% [markdown]
# # Reading our data set

# %%
import pandas as pd

g_train = pd.read_csv('train.csv')
g_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # CHECKING FOR NULL VALUES

# %%
#isnull values are age and cabin and embarked
g_train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # CHECKING PERCENTAGE OF NULL ENTIRES

# %%
print((g_train.isnull().sum()/len(g_train))*100)
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %% [markdown]
# # CABIN HAS MORE THAN 50% OF THE ENTRIES MISSING, I'LL DROP IT

# %%
#g_train = g_train.drop(columns=['Cabin'])
#g_train
g_train = g_train.drop(columns=['Cabin'])
g_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # IMPUTATION ON MISSING VALUES

# %%
#Age and Embarked
g_train['Embarked'].fillna(g_train['Embarked'].mode()[0], inplace=True)
g_train['Age'].fillna(g_train['Age'].median(), inplace=True)
g_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print((g_train.isnull().sum()/len(g_train))*100)
# Out:
# PassengerId    0.0
# Survived       0.0
# Pclass         0.0
# Name           0.0
# Sex            0.0
# Age            0.0
# SibSp          0.0
# Parch          0.0
# Ticket         0.0
# Fare           0.0
# Embarked       0.0
# dtype: float64

# %% [markdown]
# # Encoding Categorical data

# %%
#Using Label Encoding for Sex and One-hot Encoding for Embarked
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
g_train['Sex'] = label_encoder.fit_transform(g_train['Sex'])

g_train = pd.get_dummies(g_train, columns=['Embarked'], prefix='Embarked')

g_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare  Embarked_C  Embarked_Q  Embarked_S
# 0         A/5 21171   7.2500       False       False        True
# 1          PC 17599  71.2833        True       False       False
# 2  STON/O2. 3101282   7.9250       False       False        True
# ...

# %% [markdown]
# # Normalization of Numerical Features

# %%
from sklearn.preprocessing import MinMaxScaler
#Numrical columns that can be normalized are AGE, Fare, SibSp and Parch

# Identify numerical columns
numerical_columns = ['Age', 'Fare', 'SibSp', 'Parch']

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Apply Min-Max Scaling to numerical columns
g_train[numerical_columns] = scaler.fit_transform(g_train[numerical_columns])

g_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex       Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    1  0.271174  0.125
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  0.472229  0.125
# 2                             Heikkinen, Miss. Laina    0  0.321438  0.000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  0.434531  0.125
# 4                           Allen, Mr. William Henry    1  0.434531  0.000
#
#    Parch            Ticket      Fare  Embarked_C  Embarked_Q  Embarked_S
# 0    0.0         A/5 21171  0.014151       False       False        True
# 1    0.0          PC 17599  0.139136        True       False       False
# 2    0.0  STON/O2. 3101282  0.015469       False       False        True
# ...

# %% [markdown]
# # Data Visualization

# %%
import matplotlib.pyplot as plt

plt.style.use('ggplot')

# Survivors by Gender
survivors_by_gender = g_train.groupby('Sex')['Survived'].mean()
plt.figure(figsize=(6, 4))
survivors_by_gender.plot(kind='bar', color=['skyblue', 'pink'])
plt.title('Survival Rate by Gender')
plt.ylabel('Survival Rate')
plt.xlabel('Gender')
plt.xticks(rotation=0)
plt.show()

# Survivors by Passenger Class
survivors_by_class = g_train.groupby('Pclass')['Survived'].mean()
plt.figure(figsize=(6, 4))
survivors_by_class.plot(kind='bar', color='purple')
plt.title('Survival Rate by Passenger Class')
plt.ylabel('Survival Rate')
plt.xlabel('Passenger Class')
plt.xticks(rotation=0)
plt.show()

# Age Distribution of Survivors
plt.figure(figsize=(8, 5))
g_train[g_train['Survived'] == 1]['Age'].plot(kind='hist', bins=20, alpha=0.7, color='green', label='Survived')
g_train[g_train['Survived'] == 0]['Age'].plot(kind='hist', bins=20, alpha=0.7, color='red', label='Did Not Survive')
plt.title('Age Distribution of Survivors')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# Fare Distribution of Survivors
plt.figure(figsize=(8, 5))
g_train.boxplot(column='Fare', by='Survived', grid=False, patch_artist=True,
                boxprops=dict(facecolor='lightblue', color='black'),
                medianprops=dict(color='red'))
plt.title('Fare Distribution by Survival Status')
plt.suptitle('')  
plt.xlabel('Survived')
plt.ylabel('Fare')
plt.show()
