# %% [markdown]
# # DCIT 311 LAB 3

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
df = pd.read_csv('train.csv')
df
# Out:
#       ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0      1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1      2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2      4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3      5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4      7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
# ..   ...      ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 328  500  0.17783   0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391
# 329  502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 330  503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 331  504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 332  506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       18.7  394.63   2.94  33.4
# 3       18.7  396.90   5.33  36.2
# 4       15.2  395.60  12.43  22.9
# ..       ...     ...    ...   ...
# 328     19.2  395.77  15.10  17.5
# 329     21.0  391.99   9.67  22.4
# 330     21.0  396.90   9.08  20.6
# 331     21.0  396.90   5.64  23.9
# 332     21.0  396.90   7.88  11.9
#
# [333 rows x 15 columns]

# %% [markdown]
# # Data exploration

# %%
df.describe()
# Out:
#                ID        crim          zn       indus        chas         nox  \
# count  333.000000  333.000000  333.000000  333.000000  333.000000  333.000000
# mean   250.951952    3.360341   10.689189   11.293483    0.060060    0.557144
# std    147.859438    7.352272   22.674762    6.998123    0.237956    0.114955
# min      1.000000    0.006320    0.000000    0.740000    0.000000    0.385000
# 25%    123.000000    0.078960    0.000000    5.130000    0.000000    0.453000
# 50%    244.000000    0.261690    0.000000    9.900000    0.000000    0.538000
# 75%    377.000000    3.678220   12.500000   18.100000    0.000000    0.631000
# max    506.000000   73.534100  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  333.000000  333.000000  333.000000  333.000000  333.000000  333.000000
# mean     6.265619   68.226426    3.709934    9.633634  409.279279   18.448048
# std      0.703952   28.133344    1.981123    8.742174  170.841988    2.151821
# min      3.561000    6.000000    1.129600    1.000000  188.000000   12.600000
# 25%      5.884000   45.400000    2.122400    4.000000  279.000000   17.400000
# 50%      6.202000   76.700000    3.092300    5.000000  330.000000   19.000000
# 75%      6.595000   93.800000    5.116700   24.000000  666.000000   20.200000
# max      8.725000  100.000000   10.710300   24.000000  711.000000   21.200000
#
#             black       lstat        medv
# count  333.000000  333.000000  333.000000
# mean   359.466096   12.515435   22.768769
# std     86.584567    7.067781    9.173468
# min      3.500000    1.730000    5.000000
# 25%    376.730000    7.180000   17.400000
# 50%    392.050000   10.970000   21.600000
# 75%    396.240000   16.420000   25.000000
# max    396.900000   37.970000   50.000000

# %%
df.head()
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# 4     15.2  395.60  12.43  22.9

# %%
df.columns.tolist()
# Out:
# ['ID',
#  'crim',
#  'zn',
#  'indus',
#  'chas',
#  'nox',
#  'rm',
#  'age',
#  'dis',
#  'rad',
#  'tax',
#  'ptratio',
#  'black',
#  'lstat',
#  'medv']

# %%
df.isnull().sum()
# Out:
# ID         0
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %%
df = df.drop(columns=['ID'])
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4    0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 328  0.17783   0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391
# 329  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 330  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 331  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 332  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       18.7  394.63   2.94  33.4
# 3       18.7  396.90   5.33  36.2
# 4       15.2  395.60  12.43  22.9
# ..       ...     ...    ...   ...
# 328     19.2  395.77  15.10  17.5
# 329     21.0  391.99   9.67  22.4
# 330     21.0  396.90   9.08  20.6
# 331     21.0  396.90   5.64  23.9
# 332     21.0  396.90   7.88  11.9
#
# [333 rows x 14 columns]

# %%
# df.columns.tolist()
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %%
plt.figure(figsize=(20,16))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Boston correlation graph')
plt.show()

# %% [markdown]
# # Data Pre-processing

# %% [markdown]
# # Scaling the data set

# %%
scaler = MinMaxScaler()
# Features to be scaled
standardize_features = ['crim', 'zn', 'indus', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'black', 'lstat', 'medv']
df_scaled = scaler.fit_transform(df[standardize_features])
pd.DataFrame(df_scaled, columns= standardize_features)
df[standardize_features]= df_scaled
df
# Out:
#          crim     zn     indus  chas       nox        rm       age       dis  \
# 0    0.000000  0.180  0.058148     0  0.314815  0.583656  0.629787  0.308996
# 1    0.000285  0.000  0.234444     0  0.172840  0.553834  0.775532  0.400545
# 2    0.000354  0.000  0.053333     0  0.150206  0.665569  0.423404  0.514848
# 3    0.000853  0.000  0.053333     0  0.150206  0.694423  0.512766  0.514848
# 4    0.001115  0.125  0.264074     0  0.286008  0.474632  0.644681  0.462482
# ..        ...    ...       ...   ...       ...       ...       ...       ...
# 328  0.002333  0.000  0.331481     0  0.411523  0.388846  0.718085  0.132589
# 329  0.000766  0.000  0.414444     0  0.386831  0.587142  0.671277  0.140804
# 330  0.000530  0.000  0.414444     0  0.386831  0.495546  0.752128  0.120858
# 331  0.000740  0.000  0.414444     0  0.386831  0.661309  0.904255  0.108332
# 332  0.000559  0.000  0.414444     0  0.386831  0.478118  0.795745  0.143559
#
#           rad       tax   ptratio     black     lstat      medv
# 0    0.000000  0.206501  0.313953  1.000000  0.089680  0.422222
# 1    0.043478  0.103250  0.604651  1.000000  0.204470  0.368889
# 2    0.086957  0.065010  0.709302  0.994230  0.033389  0.631111
# 3    0.086957  0.065010  0.709302  1.000000  0.099338  0.693333
# 4    0.173913  0.235182  0.302326  0.996695  0.295254  0.397778
# ..        ...       ...       ...       ...       ...       ...
# 328  0.217391  0.388145  0.767442  0.997128  0.368929  0.277778
# 329  0.000000  0.162524  0.976744  0.987519  0.219095  0.386667
# 330  0.000000  0.162524  0.976744  1.000000  0.202815  0.346667
# 331  0.000000  0.162524  0.976744  1.000000  0.107892  0.420000
# 332  0.000000  0.162524  0.976744  1.000000  0.169702  0.153333
#
# [333 rows x 14 columns]

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  333.000000  333.000000  333.000000  333.000000  333.000000  333.000000
# mean     0.045616    0.106892    0.390870    0.060060    0.354206    0.523745
# std      0.099993    0.226748    0.259190    0.237956    0.236532    0.136319
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000988    0.000000    0.162593    0.000000    0.139918    0.449845
# 50%      0.003473    0.000000    0.339259    0.000000    0.314815    0.511425
# 75%      0.049939    0.125000    0.642963    0.000000    0.506173    0.587529
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#               age         dis         rad         tax     ptratio       black  \
# count  333.000000  333.000000  333.000000  333.000000  333.000000  333.000000
# mean     0.661983    0.269326    0.375375    0.423096    0.680006    0.904845
# std      0.299291    0.206783    0.380095    0.326658    0.250212    0.220093
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.419149    0.103625    0.130435    0.173996    0.558140    0.948729
# 50%      0.752128    0.204860    0.173913    0.271511    0.744186    0.987672
# 75%      0.934043    0.416160    1.000000    0.913958    0.883721    0.998322
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#             lstat        medv
# count  333.000000  333.000000
# mean     0.297611    0.394862
# std      0.195027    0.203855
# min      0.000000    0.000000
# 25%      0.150386    0.275556
# 50%      0.254967    0.368889
# 75%      0.405353    0.444444
# max      1.000000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     333 non-null    float64
#  1   zn       333 non-null    float64
#  2   indus    333 non-null    float64
#  3   chas     333 non-null    int64
#  4   nox      333 non-null    float64
#  5   rm       333 non-null    float64
#  6   age      333 non-null    float64
#  7   dis      333 non-null    float64
#  8   rad      333 non-null    float64
#  9   tax      333 non-null    float64
#  10  ptratio  333 non-null    float64
#  11  black    333 non-null    float64
#  12  lstat    333 non-null    float64
#  13  medv     333 non-null    float64
# dtypes: float64(13), int64(1)
# memory usage: 36.6 KB

# %%
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %% [markdown]
# # Training the linear regression model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
X=df[['rm']]
Y=df[['medv']]

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
predicting_y = model.predict(X_test)
predicting_y
# Out:
# array([[ 0.38568893],
#        [ 0.3891227 ],
#        [ 0.43586012],
#        [ 0.46561946],
#        [ 0.4196451 ],
#        [ 0.33322856],
#        [ 0.38511664],
#        [ 0.53887322],
#        [ 0.32903173],
#        [ 0.4501675 ],
#        [ 0.48183449],
#        [ 0.36375096],
#        [ 0.32082884],
#        [ 0.68213772],
#        [ 0.27065764],
#        [ 0.57149403],
#        [ 0.32197343],
#        [ 0.23174159],
#        [ 0.39389183],
#        [ 0.38397205],
#        [ 0.62948659],
#        [ 0.46065957],
#        [ 0.3891227 ],
#        [ 0.45798886],
#        [ 0.41735592],
#        [ 0.79850437],
#        [ 0.24108907],
#        [ 0.17241367],
#        [ 0.46581023],
#        [ 0.24127983],
#        [ 0.36604014],
#        [ 0.40591002],
#        [ 0.42498652],
#        [ 0.31796736],
#        [ 0.50434475],
#        [ 0.31758583],
#        [ 0.39122112],
#        [ 0.03410906],
#        [ 0.26798693],
#        [ 0.2637901 ],
#        [ 0.34505599],
#        [ 0.55604207],
#        [ 0.42899258],
#        [ 0.62586205],
#        [ 0.71342318],
#        [ 0.36966467],
#        [ 0.32559796],
#        [ 0.32216419],
#        [ 0.26855923],
#        [ 0.43776777],
#        [ 0.31815813],
#        [ 0.51216612],
#        [ 0.40571926],
#        [ 0.30976447],
#        [ 0.39312877],
#        [-0.00976689],
#        [ 0.3242626 ],
#        [ 0.46352105],
#        [ 0.41697439],
#        [ 0.26150092],
#        [ 0.40285778],
#        [ 0.39160265],
#        [ 0.42861105],
#        [ 0.56424496],
#        [ 0.37901216],
#        [ 0.23612918],
#        [ 0.36852008]])

# %%
predicting_y1 = model.predict([[0.583656]])
predicting_y1
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[0.45512731]])

# %%
plt.scatter(X_test,Y_test, color='blue', label='predicted values')
plt.plot(X_test,predicting_y, color='red', label='true values')
plt.xlabel('rem: average number of rooms')
plt.ylabel('medv: median home values')
plt.title('actual vs predicted Home values using average of rooms ...')
plt.show()
